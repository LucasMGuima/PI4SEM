# %% [markdown]
# $y = x^3 − 10x^2 + 6$
# **********
#
# $f(x) = Σ^∞_{n = 0} {(f(a))^n \over n!}(x-a)^n$
#
# $f(x)  =f(a)  + {f'(a) \over 1!}(x-a) + {f''(a) \over 2!}(x-a)^2 + {f'''(a) \over 3!}(x-a)^3 + ... $
#
# $6 + {{d \over dx}(x^3-10x^2+6)(0) \over 1!}x + {{d^2 \over dx^2}(x^3-10x^2+6)(0) \over 2!}x^2 + {{d^3 \over dx^3}(x^3-10x^2+6)(0) \over 3!}x^3 + ... $
#
# $6 + {0 \over 1!}x + {-20 \over 2!}x^2 + {6 \over 3!}x^3 +... $
#
# $6-10x^2 + x^3$

# %%
import numpy as np
import matplotlib.pyplot as plt
import math



x = np.linspace(-10,20,20) 
y = (x**3) - (10*(x**2))+6
#y2 = 6-(10*(x*x)) + (x*x*x)

y1 = 6-(10*(x**2))+(x**3)

novoY = 6 + ((3*x*x-20*x/(1))*(x)) + ((((6*x)-20)/2)*(x*x))+(x*x*x)

def calculoRapido(x, n_max = 4):
  #test 
  return 6+((20/math.factorial(2))*np.power(x,2)) + ((6/math.factorial(3))*np.power(x,3)) #6 + (((3*(x**2)-(20*x))/(1))*(x)) + ((((6*x)-20)/2)*(x**2))+(x**3)

#print(x)
#print(y)
y3 = calculoRapido(x)

fig, ax = plt.subplots()
fig.set_size_inches(20,8)
ax.plot(x, y, linewidth=2.0, label = "original")
#ax.plot(x, y1, linewidth=2.0, label= "test 1")
ax.plot(x, novoY, linewidth=2.0, label= "test 2")
#ax.plot(x, y2, linewidth=2.0)
ax.plot(x, y3, linewidth=2.0 , label= "test 3")
ax.grid()
ax.legend()
plt.show()
